# %%
import numpy as np
import matplotlib.pyplot as plt
import sympy as sym
import scipy as sp
from IPython.display import display, Math

# %% [markdown]
# # Graphing parabolas

# %% [markdown]
# $$4p\left(y - k\right) = \left(x - h\right)^{2}$$
#
# $$y = \frac{1}{4p}\left(x - h\right)^{2} + k$$

# %%
# parameters
a = 1 # 1/4p
h = -10
k = -2
n = 100

# x-axis points to evaluate the function
x = np.linspace(h-5,h+5,n)
y = a*(x - h)**2 + k

plt.plot(y,x)
plt.grid()
plt.axis('square')
plt.show()

# %% [markdown]
# ## Exercise

# %% [markdown]
# * Vertex: $(h,k)$
# * Focus: $(h, k + p)$
# * Directrix: $y = k - p$

# %%
# parameters
a = 1 # 1/4p
p = 1/(4*a)
h = 1
k = -2
n = 100

# x-axis points to evaluate the function
x = np.linspace(h-2,h+2,n)
y = a*(x - h)**2 + k

# plot the parabola
plt.plot(x,y, label = 'Parabola');

# plot the vertex
plt.plot(h,k, 'ro', label = 'Vertex');

# plot the focus
plt.plot(h,k + p,'go', label = 'Focus');

# plot the directrix
d = k - p
plt.plot(x[[0,-1]], [d,d], label = 'Directrix')

plt.plot()
plt.legend()
plt.grid()
#plt.axis('square')
plt.show()

# %% [markdown]
# # Creating contours from meshes in Python

# %%
X,Y = np.meshgrid(range(0,10), range(0,15))

# %%
plt.subplot(121)
plt.pcolormesh(X, edgecolor='k', lw = .1);

plt.subplot(122)
plt.pcolormesh(Y, edgecolor='k', lw = .1);

plt.show()

# %%
x = np.linspace(-np.pi, 2*np.pi, 40)
y = np.linspace(0,4*np.pi, 72)

X, Y = np.meshgrid(x,y)

fxy = np.cos(X) + np.sin(Y)
plt.imshow(fxy)
plt.show()

# %% [markdown]
# ## Exercise

# %% [markdown]
# $$\text{2D Gaussian: } Z = e^{-\left(X^{2} + Y^{2}\right)/s}$$

# %%
x = np.linspace(-2,2,100)
X, Y = np.meshgrid(x,x)
s = 1 # standard deviation

gauss2d = np.exp( -(X**2 + Y**2)/s )

plt.imshow(gauss2d)
plt.axis('off')
plt.show()
